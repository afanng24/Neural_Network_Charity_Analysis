# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
application_df = application_df.drop('NAME', 1)
application_df
# Out:
#              EIN APPLICATION_TYPE       AFFILIATION CLASSIFICATION  \
# 0       10520599              T10       Independent          C1000
# 1       10531628               T3       Independent          C2000
# 2       10547893               T5  CompanySponsored          C3000
# 3       10553066               T3  CompanySponsored          C2000
# 4       10556103               T3       Independent          C1000
# ...          ...              ...               ...            ...
# 34294  996009318               T4       Independent          C1000
# 34295  996010315               T4  CompanySponsored          C3000
# 34296  996012607               T3  CompanySponsored          C2000
# 34297  996015768               T5       Independent          C3000
# 34298  996086871               T3       Independent          C1000
#
#            USE_CASE  ORGANIZATION  STATUS     INCOME_AMT  \
# 0        ProductDev   Association       1              0
# ...

# %%
application_df = application_df.drop('EIN', 1)
application_df
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# ...

# %%
application_df.apply(lambda x: x.nunique())
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
application_types_df = application_df.APPLICATION_TYPE.value_counts()
application_types_df
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T15        2
# T29        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
replace_application = list(application_types_df[application_types_df < 200].index)

# Replace in dataframe
for app in replace_application:
    application_df.APPLICATION_TYPE = application_df.APPLICATION_TYPE.replace(app,"Other")
    
# Check to make sure binning was successful
application_df.APPLICATION_TYPE.value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
classifcation_df = application_df.CLASSIFICATION.value_counts()
classifcation_df
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4500        1
# C6100        1
# C1728        1
# C3700        1
# C2600        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
replace_class = list(classifcation_df[classifcation_df < 1800].index)

# Replace in dataframe
for cls in replace_class:
    application_df.CLASSIFICATION = application_df.CLASSIFICATION.replace(cls,"Other")
    
# Check to make sure binning was successful
application_df.CLASSIFICATION.value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
app_cat = ['APPLICATION_TYPE', 'AFFILIATION', 'CLASSIFICATION', 'USE_CASE', 'ORGANIZATION', 'INCOME_AMT', 'SPECIAL_CONSIDERATIONS']

# %%
enc = OneHotEncoder(sparse=False)

# Fit and transform the OneHotEncoder using the categorical variable list
encode_df = pd.DataFrame(enc.fit_transform(application_df[app_cat]))

# Add the encoded variable names to the dataframe
encode_df.columns = enc.get_feature_names(app_cat)

# %%
merge_df = application_df.merge(encode_df, left_index = True, right_index = True)
merge_df = merge_df.drop(['APPLICATION_TYPE', 'AFFILIATION', 'CLASSIFICATION', 'USE_CASE', 'ORGANIZATION', 'INCOME_AMT', 'SPECIAL_CONSIDERATIONS'], 1)

# %%
y = merge_df['IS_SUCCESSFUL'].values
X = merge_df.drop(['IS_SUCCESSFUL'], 1)

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# this is where we start to modify the model
# Noisy variables are removed from features
# Additional neurons are added to hidden layers 
# Additional hidden layers are added 
# The activation function of hidden layers or output layers is changed for optimization
# The model's weights are saved every 5 epochs
# The results are saved to an HDF5 file

# %%
# Create a random forest classifier.
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
rf_model = RandomForestClassifier(n_estimators=128, random_state=78)

# Fitting the model
rf_model = rf_model.fit(X_train_scaled, y_train)

# Evaluate the model
y_pred = rf_model.predict(X_test_scaled)
print(f" Random forest predictive accuracy: {accuracy_score(y_test,y_pred):.3f}")
# Out:
#  Random forest predictive accuracy: 0.711

# %%
# Import checkpoint dependencies
import os
from tensorflow.keras.callbacks import ModelCheckpoint

# Define the checkpoint path and filenames
os.makedirs("checkpoints/",exist_ok=True)
checkpoint_path = "checkpoints/weights.{epoch:02d}.hdf5"

# %%
number_input_features = 43
hidden_nodes_layer1 =  100
hidden_nodes_layer2 = 50
hidden_nodes_layer3 = 20
#this is dumb but just add another layer
hidden_nodes_layer4 = 10
# ok that almost worked just add anohter layer
hidden_nodes_layer5 = 5

#cahging the activation to tanh

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)


# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="tanh"))
# add the third layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="tanh"))

#add abitgher layer i guess
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer4, activation="tanh"))
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer5, activation="tanh"))





# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])


# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_25"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_125 (Dense)            (None, 100)               4400
# _________________________________________________________________
# dense_126 (Dense)            (None, 50)                5050
# _________________________________________________________________
# dense_127 (Dense)            (None, 20)                1020
# _________________________________________________________________
# dense_128 (Dense)            (None, 10)                210
# _________________________________________________________________
# dense_129 (Dense)            (None, 5)                 55
# _________________________________________________________________
# dense_130 (Dense)            (None, 1)                 6
# ...
# Total params: 10,741
# Trainable params: 10,741
# Non-trainable params: 0
# ...

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Create a callback that saves the model's weights every epoch
cp_callback = ModelCheckpoint(
    filepath=checkpoint_path,
    verbose=1,
    save_weights_only=True,
    save_freq= 1000)


#A changed eposhed from 100 to 200

# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=200,callbacks=[cp_callback])

# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/200
# 804/804 [==============================] - 1s 620us/step - loss: 0.5665 - accuracy: 0.7220
# Epoch 2/200
# 156/804 [====>.........................] - ETA: 0s - loss: 0.5525 - accuracy: 0.7330
# Epoch 00002: saving model to checkpoints\weights.02.hdf5
# 804/804 [==============================] - 1s 650us/step - loss: 0.5553 - accuracy: 0.7293
# Epoch 3/200
# 330/804 [===========>..................] - ETA: 0s - loss: 0.5504 - accuracy: 0.7318
# Epoch 00003: saving model to checkpoints\weights.03.hdf5
# 804/804 [==============================] - 1s 669us/step - loss: 0.5526 - accuracy: 0.7308
# Epoch 4/200
# 567/804 [====================>.........] - ETA: 0s - loss: 0.5503 - accuracy: 0.7345
# Epoch 00004: saving model to checkpoints\weights.04.hdf5
# 804/804 [==============================] - 1s 650us/step - loss: 0.5505 - accuracy: 0.7338
# Epoch 5/200
# 748/804 [==========================>...] - ETA: 0s - loss: 0.5496 - accuracy: 0.7314
# ...

# %%
number_input_features = 43
hidden_nodes_layer1 =  100
hidden_nodes_layer2 = 50
hidden_nodes_layer3 = 20
#try another layer i guess
hidden_nodes_layer4 = 10
hidden_nodes_layer5 = 5



nn_new = tf.keras.models.Sequential()

# First hidden layer
nn_new.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn_new.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="tanh"))

#third layer
nn_new.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="tanh"))

#fourth layer
nn_new.add(tf.keras.layers.Dense(units=hidden_nodes_layer4, activation="tanh"))
nn_new.add(tf.keras.layers.Dense(units=hidden_nodes_layer5, activation="tanh"))



# Output layer
nn_new.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the model
nn_new.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Restore the model weights
nn_new.load_weights("checkpoints/weights.100.hdf5")

# Evaluate the model using the test data
model_loss, model_accuracy = nn_new.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5678 - accuracy: 0.7307
# Loss: 0.5678068995475769, Accuracy: 0.7307288646697998

# %%
# Export our model to HDF5 file
nn_new.save("AlphabetSoupCharity_Optimization.h5")

# %%
# Import the model to a new object
nn_imported = tf.keras.models.load_model("AlphabetSoupCharity_Optimization.h5")

# %%
# Evaluate the completed model using the test data
model_loss, model_accuracy = nn_imported.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5678 - accuracy: 0.7307
# Loss: 0.5678068995475769, Accuracy: 0.7307288646697998
